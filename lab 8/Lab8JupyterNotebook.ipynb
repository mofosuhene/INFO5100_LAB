# %% [markdown]
# # Lab 8: Data Visualizations using Python

# %% [markdown]
# 1. Download Python Anaconda & Jupyter notebook extension (on VSCode)
# 2. Create a virtual environment using conda.
#     ```bash
#         conda create --name info5100
#     ```
# 3. Activate the virtual environment
#     ```bash
#         conda activate info5100
#     ```
# 4. Install the following libraries:
#     - pandas
#     ```bash
#         pip install pandas
#     ```
#     - matplotlib
#     ```bash
#         pip install matplotlib
#     ```
#     - seaborn
#     ```bash
#         pip install seaborn
#     ```
# 5. All Set to Run This Jupyter Notebook (.ipynb file)
# 6. Select the Kernal in Top Right Corner (on VSCode)
# 7. In the end to exit from the virtual environment:
#     ```bash
#         conda deactivate
#     ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# If all the libraries are installed, the above cell should run successfully.

# %%
# Loading a dataset:
iris_dataframe = pd.read_csv('IrisDataset/Iris.csv')

# %%
iris_dataframe
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris_dataframe.head(-10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
#
# [140 rows x 6 columns]

# %%
iris_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_dataframe["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## Line Plot
#
# ### Univariate
# Visual representation of the relationship of a single column in a dataset.

# %%
plt.plot(iris_dataframe["Id"], iris_dataframe['PetalLengthCm'])
plt.title("Iris Petal Length")
plt.xlabel("Id")
plt.ylabel("Petal Width (cm)")
# plt.show()
# Out:
# Text(0, 0.5, 'Petal Width (cm)')

# %%
# adding gird-lines
plt.grid(True)

plt.plot(iris_dataframe["Id"], iris_dataframe['PetalLengthCm'])
plt.title("Iris Petalpal Length")
plt.xlabel("Id")
plt.ylabel("Petal Length (cm)")
#Set x-axis for every 10 units
plt.xticks(range(0, max(iris_dataframe["Id"]) + 1, 15))  
plt.show()

# %% [markdown]
# ## Scatter Plot
#
# ### Bivariate
# Visual representation of the relationship between two variables in a dataset.

# %%
plt.grid(False)
plt.scatter(iris_dataframe["PetalLengthCm"], iris_dataframe["PetalWidthCm"])
plt.title("Iris Petal Length vs Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
# Out:
# Text(0, 0.5, 'Petal Width (cm)')

# %% [markdown]
# ### Multivariate
# Visual representation of the relationship between three or more columns/ variables in a dataset.

# %%
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50

iris_species_color = {"Iris-setosa": "black", 
                      "Iris-versicolor": "blue", 
                      "Iris-virginica":"green"}

for species, species_color in iris_species_color.items():
    # creating a data frame for a specific value for 'Species' column:
    species_dataframe = iris_dataframe[iris_dataframe["Species"] == species]
    # parameter c - color
    plt.scatter(species_dataframe["PetalLengthCm"], species_dataframe["PetalWidthCm"], c = species_color, label=species)

plt.grid(True)
plt.title("Iris Petal Length vs Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.legend()

# %% [markdown]
# ## Histograms

# %%
sns.histplot(data=iris_dataframe, x="PetalLengthCm")
plt.title("Petal Length Distribution")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.histplot(data=iris_dataframe, x="PetalLengthCm")
plt.title("Petal Length Distribution")
plt.grid(axis="y")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
plt.xticks(range(0, 10, 2))
plt.yticks(range(1, 50, 4))
# Out:
# ([<matplotlib.axis.YTick at 0x1cb81a30d10>,
#   <matplotlib.axis.YTick at 0x1cb81a1ef60>,
#   <matplotlib.axis.YTick at 0x1cb81a52bd0>,
#   <matplotlib.axis.YTick at 0x1cb81a32f30>,
#   <matplotlib.axis.YTick at 0x1cb81a8b470>,
#   <matplotlib.axis.YTick at 0x1cb81a8b1a0>,
#   <matplotlib.axis.YTick at 0x1cb81a338c0>,
#   <matplotlib.axis.YTick at 0x1cb81a517c0>,
#   <matplotlib.axis.YTick at 0x1cb81a51430>,
#   <matplotlib.axis.YTick at 0x1cb81aa84d0>,
#   <matplotlib.axis.YTick at 0x1cb81aa8da0>,
#   <matplotlib.axis.YTick at 0x1cb81aa96a0>,
#   <matplotlib.axis.YTick at 0x1cb81a1ff80>],
#  [Text(0, 1, '1'),
#   Text(0, 5, '5'),
#   Text(0, 9, '9'),
#   Text(0, 13, '13'),
#   Text(0, 17, '17'),
#   Text(0, 21, '21'),
#   Text(0, 25, '25'),
#   Text(0, 29, '29'),
#   Text(0, 33, '33'),
#   Text(0, 37, '37'),
#   Text(0, 41, '41'),
#   Text(0, 45, '45'),
#   Text(0, 49, '49')])

# %% [markdown]
# ## Pair Plot
# Introduce pairwise relationships.

# %%
sns.pairplot(iris_dataframe, hue="Species")
plt.show()

# %% [markdown]
# ## Box Plots

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="Set3")

# Add labels and title
plt.title("Box Plot of Sepal Length by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Length (cm)")
plt.show()
# Out:
# /var/folders/3m/tt_kbz7d2tx3f5cx3v4nd4940000gn/T/ipykernel_54584/1198724479.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="Set3")

# %% [markdown]
# ## Swarm Plot + Box Plot

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="pastel")
sns.swarmplot(x="Species", y="SepalLengthCm", data=iris_dataframe, color=".25")
plt.title("Box and Swarm Plot of Petal Width by Species")
plt.xlabel("Species")
plt.ylabel("Petal Width (cm)")
plt.show()
# Out:
# /var/folders/3m/tt_kbz7d2tx3f5cx3v4nd4940000gn/T/ipykernel_54584/3450600594.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="pastel")

# %% [markdown]
# ## Kernel Density Plot (KDE)
#
# KDE plot helps to visualize the distribution of data in a dataset

# %%
# Create a KDE plot
plt.figure(figsize=(8, 6))
sns.kdeplot(data=iris_dataframe, x="SepalLengthCm", hue="Species", fill=True, common_norm=False, palette="crest", alpha=0.2)

# Add labels and title
plt.title("Kernel Density Plot of Sepal Length by Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## Violin Plot (Box Plot + KDE)
#
# A statistical graphic that shows the distribution of numerical data by combining a box plot and a kernel density plot.

# %%
sns.violinplot(x='Species', y='PetalLengthCm', data=iris_dataframe)
plt.title('Violin Plot of Petal Length by Species')
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ## Correlation Heat Maps

# %%
correlation = iris_dataframe.iloc[:, :-1].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correl ation Heatmap')
plt.show()

# %% [markdown]
# ## Best Practices
#
# 1. Proper labeling for the axes.
# 2. Color choice considerations.
# 3. Scale and proportion
